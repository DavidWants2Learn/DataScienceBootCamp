# %%
#def myfunction(x,a,b):
# return (a*x*np.cos(b*x))
# y = axcosbx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("abalone.csv")
df.head(3)
# Out:
#   gender  length  diameter  height  whole-wt  shucked-wt  viscera-wt  \
# 0      M   0.455     0.365   0.095    0.5140      0.2245      0.1010
# 1      M   0.350     0.265   0.090    0.2255      0.0995      0.0485
# 2      F   0.530     0.420   0.135    0.6770      0.2565      0.1415
#
#    shell-wt  rings
# 0      0.15     15
# 1      0.07      7
# 2      0.21      9

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f874a64e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a393c88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a346240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a36e7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a314d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a2c52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a2ec860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a294e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f874a294e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a26a908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a212e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a1c3438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a1e99b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a192f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a1434e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a169a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f874a112fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a0c1588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a0e8b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a09a0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a03f630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a068ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f874a01b160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749fc06d8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8749fe8c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749f97208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749f3e780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749f67cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749f172b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749ebe828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749ee7da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749e95358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8749e3d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749e65e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749e15400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749e3a978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749de5ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749d954a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749d3ca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749d63f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8749d15550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749d3aac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749ced080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749c945f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749cbab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749c6c128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749c126a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749c38c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8749bec1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749b92748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749bbacc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749b6a278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749b127f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749abbd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749ae9320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749a8f898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8749ab8e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749a683c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749a11940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749a3aeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f87499ea470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f87499909e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f87499b7f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8749967518>]],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
Y = df["rings"].values

# %%
df["gender"] = df["gender"].astype("category").cat.codes

# %%
df = df.drop(columns=["rings"])

# %%
(df["gender"]).head(3)
# Out:
# 0    2
# 1    2
# 2    0
# Name: gender, dtype: int8

# %%
X_train, X_test, y_train, y_test = train_test_split((df * 1).values, Y, test_size=0.2)

print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (3341, 8) (3341,)
# (836, 8) (836,)

# %%
LR = LinearRegression()
LR.fit(X_train, y_train)
LR.score(X_test, y_test)
# Out:
# 0.5296601919700892
